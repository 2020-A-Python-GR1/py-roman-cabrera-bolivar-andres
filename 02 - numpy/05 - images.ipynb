# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
from scipy import misc

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/2018-B-GR1-Python/python/master/Imagen%20como%20un%20arreglo.PNG "Logo Title Text 1")

# %%
mapache = misc.face()
mapache.shape
# Out:
# (768, 1024, 3)

# %%
mapache.T
# Out:
# array([[[121,  89,  73, ...,  87,  85,  85],
#         [138, 110,  94, ...,  94,  95,  97],
#         [153, 130, 115, ..., 107, 112, 111],
#         ...,
#         [119, 118, 117, ..., 120, 121, 120],
#         [131, 134, 133, ..., 119, 120, 119],
#         [139, 146, 144, ..., 119, 120, 118]],
#
#        [[112,  82,  66, ..., 106, 101, 101],
#         [129, 103,  87, ..., 110, 111, 113],
#         [144, 122, 108, ..., 124, 127, 126],
#         ...,
#         [126, 125, 126, ..., 158, 157, 156],
#         [136, 141, 142, ..., 157, 156, 155],
#         [144, 153, 153, ..., 158, 156, 154]],
#
#        [[131, 100,  84, ...,  76,  72,  74],
#         [148, 121, 105, ...,  81,  82,  84],
#         [165, 143, 126, ...,  92,  96,  97],
#         ...,
#         [ 74,  71,  71, ...,  97,  96,  95],
#         [ 82,  87,  87, ...,  96,  94,  93],
#         [ 90,  99,  98, ...,  95,  94,  92]]], dtype=uint8)

# %%
plt.imshow(np.flip(mapache))
plt.show()

# %%
def chkImg(img): 
    if len(img) < 0:
        res = True
    res = all(ele == img[0] for ele in img) 
    return res

#Sacar los valores RGB unicos en una imagen
img = misc.face() #np.random.randint(255,size=(100,100,3))
arr = img.reshape(-1, img.shape[2])
print(chkImg(arr[]))




#print(color.count(True))
# Out:
# False
